# %%
import requests
import json
import pandas as pd

# %%
res = requests.get("https://zcczendeskcodingchallenge4590.zendesk.com/api/v2/requests.json", auth = ("brohan2800@gmail.com/token", "NwbAkRLBOOw84TYritRdxE1KG2YElLO3OINem1Jx"))
print(res.ok)

#data = res.json()
#df = pd.DataFrame.from_dict(data)
#df_nested_list = pd.json_normalize(data, record_path= ['requests'])
#df_nested_list.to_csv('tickets.csv')
#df_nested_list.to_csv('resp.csv', index=False)
df_nested_list
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
df_nested_list("display.max_rows")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-d2e425fa6bfe> in <module>
# ----> 1 df_nested_list("display.max_rows")
#
# TypeError: 'DataFrame' object is not callable

# %%
#for i in range (2, len(df_nested_list['id'].values)):
#    print("Ticket with subject '" +
#df_nested_list.loc[(df_nested_list['id']) == 4, 'subject'].values[0]
for i in range (2, len(df_nested_list['id'].values)):
    print("Ticket with subject '" + df_nested_list.loc[(df_nested_list['id']) == i, 'subject'].values[0] + " opened by " + str(df_nested_list.loc[(df_nested_list['id']) == i, 'requester_id'].values[0]) + " on " + str(df_nested_list.loc[(df_nested_list['id']) == i, 'updated_at'].values[0]))
    #print(i)
# Out:
# Ticket with subject 'velit eiusmod reprehenderit officia cupidatat opened by 1902273845184 on 2021-11-26T03:22:45Z
# Ticket with subject 'excepteur laborum ex occaecat Lorem opened by 1902273845184 on 2021-11-26T03:22:45Z
# Ticket with subject 'ad sunt qui aute ullamco opened by 1902273845184 on 2021-11-26T03:22:46Z
# Ticket with subject 'aliquip mollit quis laborum incididunt opened by 1902273845184 on 2021-11-26T03:22:47Z
# Ticket with subject 'nisi aliquip ipsum nostrud amet opened by 1902273845184 on 2021-11-26T03:22:47Z
# Ticket with subject 'cillum quis nostrud labore amet opened by 1902273845184 on 2021-11-26T03:22:48Z
# Ticket with subject 'proident est nisi non irure opened by 1902273845184 on 2021-11-26T03:22:48Z
# Ticket with subject 'veniam ea eu minim aute opened by 1902273845184 on 2021-11-26T03:22:49Z
# Ticket with subject 'magna reprehenderit nisi est cillum opened by 1902273845184 on 2021-11-26T03:22:49Z
# ...

# %%
with open('tickets.json') as f:
    data = json.load(f)

# %%
response = data['tickets']
response
# Out:
# [{'requester_id': 1,
#   'assignee_id': 5,
#   'subject': 'velit eiusmod reprehenderit officia cupidatat',
#   'description': 'Aute ex sunt culpa ex ea esse sint cupidatat aliqua ex consequat sit reprehenderit. Velit labore proident quis culpa ad duis adipisicing laboris voluptate velit incididunt minim consequat nulla. Laboris adipisicing reprehenderit minim tempor officia ullamco occaecat ut laborum.\n\nAliquip velit adipisicing exercitation irure aliqua qui. Commodo eu laborum cillum nostrud eu. Mollit duis qui non ea deserunt est est et officia ut excepteur Lorem pariatur deserunt.',
#   'tags': ['est', 'nisi', 'incididunt']},
#  {'requester_id': 2,
#   'assignee_id': 8,
#   'subject': 'excepteur laborum ex occaecat Lorem',
# ...

# %%
with open("tickets.json") as datafile:
    for line in datafile:
        data = json.loads(line)
    ww = pd.DataFrame(data)
ww.head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-39-d47fddab2d1c> in <module>
#       1 with open("tickets.json") as datafile:
#       2     for line in datafile:
# ----> 3         data = json.loads(line)
#       4     ww = pd.DataFrame(data)
#       5 ww.head()
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...

# %%
df = pd.read_json("tickets.json")
bn = pd.DataFrame(df.values.tolist())['tickets']
pd.DataFrame(bn)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-f66eca87e593> in <module>
#       1 df = pd.read_json("tickets.json")
# ----> 2 bn = pd.DataFrame(df.values.tolist())['tickets']
#       3 pd.DataFrame(bn)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
# ...

# %%
with open("")
